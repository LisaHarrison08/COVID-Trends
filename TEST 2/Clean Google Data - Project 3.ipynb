# %% [markdown]
# # Clean Google Mobility Data

# %%
# Dependencies and Setup
import json
import os
import pandas as pd
import urllib.request
import requests
# from config import db_pwd, db_user
from sqlalchemy import create_engine

# %% [markdown]
# ## Store Google CSV into DataFrame

# %%
csv_file = "Resources/google_mob_US.csv"
google_data_df = pd.read_csv(csv_file)
google_data_df.head()
# Out:
#    Unnamed: 0    State        date  retail_and_recreation  \
# 0           0  Alabama  2020-02-15                    5.0
# 1           1  Alabama  2020-02-16                    0.0
# 2           2  Alabama  2020-02-17                    3.0
# 3           3  Alabama  2020-02-18                   -4.0
# 4           4  Alabama  2020-02-19                    4.0
#
#    grocery_and_pharmacy  parks  transit_stations  workplaces  residential
# 0                   2.0   39.0               7.0         2.0         -1.0
# 1                  -2.0   -7.0               3.0        -1.0          1.0
# 2                   0.0   17.0               7.0       -17.0          4.0
# 3                  -3.0  -11.0              -1.0         1.0          2.0
# 4                   1.0    6.0               4.0         1.0          0.0

# %% [markdown]
# ### Rename the dataframe with select columns

# %%
google_data_df = google_data_df.rename(columns = {"State":'states', "date":'dates', "retail_and_recreation":'retail_recreation',
                            "grocery_and_pharmacy":'grocery_pharmacy', "parks":'parks', "transit_stations":"transit", "workplaces":"workplaces", "residential":"residential"})
google_data_df
# Out:
#         Unnamed: 0   states       dates  retail_recreation  grocery_pharmacy  \
# 0                0  Alabama  2020-02-15                5.0               2.0
# 1                1  Alabama  2020-02-16                0.0              -2.0
# 2                2  Alabama  2020-02-17                3.0               0.0
# 3                3  Alabama  2020-02-18               -4.0              -3.0
# 4                4  Alabama  2020-02-19                4.0               1.0
# ...            ...      ...         ...                ...               ...
# 456457      456457  Wyoming  2020-07-29                NaN               NaN
# 456458      456458  Wyoming  2020-07-30                NaN               NaN
# 456459      456459  Wyoming  2020-07-31                NaN               NaN
# 456460      456460  Wyoming  2020-08-03                NaN               NaN
# 456461      456461  Wyoming  2020-08-04                NaN               NaN
#
#         parks  transit  workplaces  residential
# 0        39.0      7.0         2.0         -1.0
# 1        -7.0      3.0        -1.0          1.0
# 2        17.0      7.0       -17.0          4.0
# 3       -11.0     -1.0         1.0          2.0
# 4         6.0      4.0         1.0          0.0
# ...       ...      ...         ...          ...
# 456457    NaN      NaN       -29.0          NaN
# 456458    NaN      NaN       -29.0          NaN
# 456459    NaN      NaN       -26.0          NaN
# 456460    NaN      NaN       -26.0          NaN
# 456461    NaN      NaN       -21.0          NaN
#
# [456462 rows x 9 columns]

# %%
google_df = google_data_df[["states", "dates", "retail_recreation",
                            "grocery_pharmacy", "parks", "transit", "workplaces", "residential"]]
google_df
# Out:
#          states       dates  retail_recreation  grocery_pharmacy  parks  \
# 0       Alabama  2020-02-15                5.0               2.0   39.0
# 1       Alabama  2020-02-16                0.0              -2.0   -7.0
# 2       Alabama  2020-02-17                3.0               0.0   17.0
# 3       Alabama  2020-02-18               -4.0              -3.0  -11.0
# 4       Alabama  2020-02-19                4.0               1.0    6.0
# ...         ...         ...                ...               ...    ...
# 456457  Wyoming  2020-07-29                NaN               NaN    NaN
# 456458  Wyoming  2020-07-30                NaN               NaN    NaN
# 456459  Wyoming  2020-07-31                NaN               NaN    NaN
# 456460  Wyoming  2020-08-03                NaN               NaN    NaN
# 456461  Wyoming  2020-08-04                NaN               NaN    NaN
#
#         transit  workplaces  residential
# 0           7.0         2.0         -1.0
# 1           3.0        -1.0          1.0
# 2           7.0       -17.0          4.0
# 3          -1.0         1.0          2.0
# 4           4.0         1.0          0.0
# ...         ...         ...          ...
# 456457      NaN       -29.0          NaN
# 456458      NaN       -29.0          NaN
# 456459      NaN       -26.0          NaN
# 456460      NaN       -26.0          NaN
# 456461      NaN       -21.0          NaN
#
# [456462 rows x 8 columns]

# %%
# # Reseting the index and saving the cleaned file to csv
# clean_google_mob_US_df = clean_google_mob_US_df.reset_index(drop = True)
# clean_google_mob_US_df.to_csv("../Data/clean_google_mob_US.csv")

# %%
google_df["SMA_retail_recreation"] = google_df.iloc[:,2].rolling(window=30).mean()
google_df["SMA_grocery_pharmacy"] = google_df.iloc[:,3].rolling(window=30).mean()
google_df["SMA_parks"] = google_df.iloc[:,4].rolling(window=30).mean()
google_df["SMA_transit"] = google_df.iloc[:,5].rolling(window=30).mean()
google_df["SMA_workplaces"] = google_df.iloc[:,6].rolling(window=30).mean()
google_df["SMA_residential"] = google_df.iloc[:,7].rolling(window=30).mean()
google_df.head(20)
# Out:
#      states       dates  retail_recreation  grocery_pharmacy  parks  transit  \
# 0   Alabama  2020-02-15                5.0               2.0   39.0      7.0
# 1   Alabama  2020-02-16                0.0              -2.0   -7.0      3.0
# 2   Alabama  2020-02-17                3.0               0.0   17.0      7.0
# 3   Alabama  2020-02-18               -4.0              -3.0  -11.0     -1.0
# 4   Alabama  2020-02-19                4.0               1.0    6.0      4.0
# 5   Alabama  2020-02-20               -7.0              -6.0  -25.0     -1.0
# 6   Alabama  2020-02-21                3.0               0.0   12.0      9.0
# 7   Alabama  2020-02-22                5.0               4.0   46.0     13.0
# 8   Alabama  2020-02-23                3.0               2.0   24.0     16.0
# 9   Alabama  2020-02-24               -2.0              -3.0  -13.0      2.0
# 10  Alabama  2020-02-25                7.0               3.0   27.0      7.0
# 11  Alabama  2020-02-26               16.0               5.0    7.0     11.0
# 12  Alabama  2020-02-27               12.0               6.0   14.0      9.0
# 13  Alabama  2020-02-28               12.0               6.0   20.0     10.0
# 14  Alabama  2020-02-29               15.0              10.0   55.0     20.0
# 15  Alabama  2020-03-01               16.0              10.0   53.0     21.0
# 16  Alabama  2020-03-02                8.0               4.0   -2.0      5.0
# 17  Alabama  2020-03-03               20.0              15.0   33.0      5.0
# 18  Alabama  2020-03-04                7.0               0.0   -8.0      2.0
# 19  Alabama  2020-03-05                7.0               6.0    0.0      4.0
#
#     workplaces  residential  SMA_retail_recreation  SMA_grocery_pharmacy  \
# 0          2.0         -1.0                    NaN                   NaN
# 1         -1.0          1.0                    NaN                   NaN
# 2        -17.0          4.0                    NaN                   NaN
# 3          1.0          2.0                    NaN                   NaN
# 4          1.0          0.0                    NaN                   NaN
# 5          0.0          3.0                    NaN                   NaN
# 6          1.0          0.0                    NaN                   NaN
# 7          6.0         -1.0                    NaN                   NaN
# 8          2.0          0.0                    NaN                   NaN
# 9         -2.0          2.0                    NaN                   NaN
# 10        -1.0          0.0                    NaN                   NaN
# 11         0.0         -1.0                    NaN                   NaN
# 12         2.0         -1.0                    NaN                   NaN
# 13         1.0         -1.0                    NaN                   NaN
# 14         5.0         -3.0                    NaN                   NaN
# 15         4.0         -2.0                    NaN                   NaN
# 16         2.0          0.0                    NaN                   NaN
# 17         2.0         -1.0                    NaN                   NaN
# 18         0.0          1.0                    NaN                   NaN
# 19         2.0          1.0                    NaN                   NaN
#
#     SMA_parks  SMA_transit  SMA_workplaces  SMA_residential
# 0         NaN          NaN             NaN              NaN
# 1         NaN          NaN             NaN              NaN
# 2         NaN          NaN             NaN              NaN
# 3         NaN          NaN             NaN              NaN
# 4         NaN          NaN             NaN              NaN
# 5         NaN          NaN             NaN              NaN
# 6         NaN          NaN             NaN              NaN
# 7         NaN          NaN             NaN              NaN
# 8         NaN          NaN             NaN              NaN
# 9         NaN          NaN             NaN              NaN
# 10        NaN          NaN             NaN              NaN
# 11        NaN          NaN             NaN              NaN
# 12        NaN          NaN             NaN              NaN
# 13        NaN          NaN             NaN              NaN
# 14        NaN          NaN             NaN              NaN
# 15        NaN          NaN             NaN              NaN
# 16        NaN          NaN             NaN              NaN
# 17        NaN          NaN             NaN              NaN
# 18        NaN          NaN             NaN              NaN
# 19        NaN          NaN             NaN              NaN

# %%
# # Reseting the index and saving the cleaned file to csv
google_us_df = google_df.reset_index(drop = True)
google_us_df.to_csv("google_us.csv")

# %%
# Selecting only the data for the US. This dropped the data to 456634 rows × 14 columns
google_mob_VA = google_df.loc[google_df["states"] == "Virginia"]
google_mob_VA = google_mob_VA.reset_index(drop = True)
google_mob_VA
# Out:
#          states       dates  retail_recreation  grocery_pharmacy  parks  \
# 0      Virginia  2020-02-15                2.0               2.0    3.0
# 1      Virginia  2020-02-16                4.0               0.0    9.0
# 2      Virginia  2020-02-17                8.0               2.0   41.0
# 3      Virginia  2020-02-18                1.0               2.0   22.0
# 4      Virginia  2020-02-19                2.0               2.0    6.0
# ...         ...         ...                ...               ...    ...
# 21343  Virginia  2020-07-31               -7.0               2.0   55.0
# 21344  Virginia  2020-08-01               -2.0              13.0    NaN
# 21345  Virginia  2020-08-02               -1.0               6.0    NaN
# 21346  Virginia  2020-08-03                0.0              18.0   18.0
# 21347  Virginia  2020-08-04               -1.0              -3.0   42.0
#
#        transit  workplaces  residential  SMA_retail_recreation  \
# 0          4.0         0.0          0.0               0.400000
# 1         -1.0         0.0          0.0               0.433333
# 2         -6.0       -27.0          6.0               0.800000
# 3          4.0         3.0          0.0               0.766667
# 4          3.0         2.0          0.0               1.166667
# ...        ...         ...          ...                    ...
# 21343      NaN       -45.0         14.0              -0.666667
# 21344      NaN       -12.0          NaN              -1.200000
# 21345      NaN       -13.0          NaN              -1.566667
# 21346      NaN       -44.0         14.0              -1.033333
# 21347      NaN       -62.0         21.0              -0.866667
#
#        SMA_grocery_pharmacy  SMA_parks  SMA_transit  SMA_workplaces  \
# 0                       NaN        NaN   -10.366667      -25.700000
# 1                       NaN        NaN   -10.266667      -24.666667
# 2                       NaN        NaN   -10.000000      -24.500000
# 3                       NaN        NaN    -9.433333      -23.366667
# 4                       NaN        NaN    -8.533333      -22.166667
# ...                     ...        ...          ...             ...
# 21343              8.666667        NaN          NaN      -37.166667
# 21344              8.400000        NaN          NaN      -36.033333
# 21345              7.733333        NaN          NaN      -34.233333
# 21346              7.900000        NaN          NaN      -34.900000
# 21347              7.866667        NaN          NaN      -36.400000
#
#        SMA_residential
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 21343              NaN
# 21344              NaN
# 21345              NaN
# 21346              NaN
# 21347              NaN
#
# [21348 rows x 14 columns]

# %%
# Grouping by date, so we can get all the data for all states into one date
# skipnabool, default is True, and all NA/null values are excluded, when computing the result.
data_by_date_VA_df = pd.DataFrame(google_mob_VA.groupby("dates").mean())
data_by_date_VA_df.reset_index(inplace = True)
data_by_date_VA_df
# Out:
#           dates  retail_recreation  grocery_pharmacy      parks    transit  \
# 0    2020-02-15           7.033898          1.703390   1.652174   5.875000
# 1    2020-02-16           5.916667          0.087719   3.520000   3.189189
# 2    2020-02-17           6.327434          0.435897  33.157895   1.833333
# 3    2020-02-18           2.787611          1.947826  19.894737   4.545455
# 4    2020-02-19           3.333333          2.104348   0.050000   3.191489
# ..          ...                ...               ...        ...        ...
# 167  2020-07-31          -7.768293          1.766234  22.352941 -14.181818
# 168  2020-08-01          -5.814815          6.671875  52.500000  -5.944444
# 169  2020-08-02          -7.527778          2.241379  55.947368  -4.135135
# 170  2020-08-03          -6.410959          3.485714   8.210526 -17.476190
# 171  2020-08-04          -5.847222          0.352113  32.058824 -20.478261
#
#      workplaces  residential  SMA_retail_recreation  SMA_grocery_pharmacy  \
# 0      0.604396    -0.482759              -8.546237              1.238667
# 1      0.431818    -0.448276              -8.282424              1.136054
# 2    -19.236220     5.015873              -7.633951              1.117687
# 3      2.492063    -0.267606              -7.303704              1.110204
# 4      1.769841    -0.152778              -6.801235              1.252381
# ..          ...          ...                    ...                   ...
# 167  -32.844961    10.920000              -8.374762              2.038506
# 168  -10.567010     3.724138              -8.690821              1.997661
# 169  -14.197802     3.440000              -8.911594              1.625731
# 170  -32.155039    10.581818              -8.233333              1.618129
# 171  -38.798450    12.745098              -8.141176              1.763743
#
#      SMA_parks  SMA_transit  SMA_workplaces  SMA_residential
# 0          NaN   -20.316667      -27.334510        10.044444
# 1          NaN   -22.645455      -26.292593         9.622222
# 2          NaN   -21.636364      -26.077395         9.383333
# 3          NaN   -20.518182      -24.853488         8.944444
# 4          NaN   -19.306061      -23.726357         8.527778
# ..         ...          ...             ...              ...
# 167  42.270833   -17.346237      -29.136066        10.301389
# 168  42.129167   -18.174444      -28.885263        10.061111
# 169  41.362500   -17.698925      -27.541111         9.659722
# 170  49.814286   -16.814583      -27.739891         9.944444
# 171  37.866667   -17.365625      -28.373224        10.174667
#
# [172 rows x 13 columns]

# %%
# # Reseting the index and saving the cleaned file to csv
data_by_date_VA_df.to_csv("google_mob_VAA.csv")

# %%
# Grouping by date, so we can get all the data for all states into one date
# skipnabool, default is True, and all NA/null values are excluded, when computing the result.
data_by_date_US_df = pd.DataFrame(google_df.groupby("dates").mean())
data_by_date_US_df.reset_index(inplace = True)
data_by_date_US_df
# Out:
#           dates  retail_recreation  grocery_pharmacy      parks   transit  \
# 0    2020-02-15           6.438490          2.379197  16.658416  4.307071
# 1    2020-02-16           7.986974          2.511178  17.796895  3.752110
# 2    2020-02-17           3.865043         -0.345417  27.884146  1.819767
# 3    2020-02-18          -0.193205         -1.269649   5.354559  2.244722
# 4    2020-02-19           2.079870          0.579322   7.988439  2.475737
# ..          ...                ...               ...        ...       ...
# 167  2020-07-31          -3.338162          5.251713  68.145488 -3.857418
# 168  2020-08-01          -4.665718          7.484454  81.304189  1.590763
# 169  2020-08-02          -1.311211          4.662641  76.178253  0.365062
# 170  2020-08-03           1.516552          7.114116  56.354717 -6.108588
# 171  2020-08-04          -1.150339          4.792763  59.988506 -8.247805
#
#      workplaces  residential  SMA_retail_recreation  SMA_grocery_pharmacy  \
# 0      0.440225    -0.550276              -3.564387              3.430499
# 1      0.484000    -0.661800              -3.274811              3.276794
# 2    -17.579826     4.363513              -3.060386              3.143699
# 3     -0.005492     0.794469              -2.998998              2.946242
# 4      0.884418     0.177460              -2.630322              2.952743
# ..          ...          ...                    ...                   ...
# 167  -28.497639     7.663490              -3.941568              4.445276
# 168   -9.850601     2.382151              -4.490288              4.048256
# 169  -12.422342     2.327806              -4.641958              3.563785
# 170  -27.709433     7.375178              -3.788574              3.574979
# 171  -29.297317     8.288040              -3.624402              3.757661
#
#      SMA_parks  SMA_transit  SMA_workplaces  SMA_residential
# 0    38.969935   -12.050508      -24.100974         7.729787
# 1    35.700233   -12.121905      -23.112474         7.381628
# 2    33.313281   -11.794194      -22.794246         7.208911
# 3    33.360937   -11.221212      -21.849528         6.901980
# 4    33.446875   -10.572796      -20.857547         6.536964
# ..         ...          ...             ...              ...
# 167  49.408766    -8.166667      -26.052553         7.810243
# 168  48.663862    -8.356387      -25.665812         7.614323
# 169  48.253074    -8.162613      -24.449131         7.253646
# 170  47.636452    -7.875407      -24.548064         7.430512
# 171  47.159057    -8.081686      -24.943333         7.672100
#
# [172 rows x 13 columns]

# %%
# # Reseting the index and saving the cleaned file to csv
data_by_date_US_df.to_csv("google_mob_US.csv")

# %%
start_date = "2020-02-15"
end_date = "2020-03-01"
mask = (google_df["dates"] > start_date) & (google_df["dates"] <= end_date)
cut_date_df = google_df.loc[mask]
cut_date_df
# Out:
#          states       dates  retail_recreation  grocery_pharmacy  parks  \
# 1       Alabama  2020-02-16                0.0              -2.0   -7.0
# 2       Alabama  2020-02-17                3.0               0.0   17.0
# 3       Alabama  2020-02-18               -4.0              -3.0  -11.0
# 4       Alabama  2020-02-19                4.0               1.0    6.0
# 5       Alabama  2020-02-20               -7.0              -6.0  -25.0
# ...         ...         ...                ...               ...    ...
# 456344  Wyoming  2020-02-24                NaN               NaN    NaN
# 456345  Wyoming  2020-02-25                NaN              -9.0    NaN
# 456346  Wyoming  2020-02-26                NaN              -4.0    NaN
# 456347  Wyoming  2020-02-27                NaN               NaN    NaN
# 456348  Wyoming  2020-02-28                NaN               4.0    NaN
#
#         transit  workplaces  residential  SMA_retail_recreation  \
# 1           3.0        -1.0          1.0                    NaN
# 2           7.0       -17.0          4.0                    NaN
# 3          -1.0         1.0          2.0                    NaN
# 4           4.0         1.0          0.0                    NaN
# 5          -1.0         0.0          3.0                    NaN
# ...         ...         ...          ...                    ...
# 456344      NaN        -4.0          NaN                    NaN
# 456345      NaN         2.0          NaN                    NaN
# 456346      NaN        -6.0          NaN                    NaN
# 456347      NaN         0.0          NaN                    NaN
# 456348      NaN         NaN          NaN                    NaN
#
#         SMA_grocery_pharmacy  SMA_parks  SMA_transit  SMA_workplaces  \
# 1                        NaN        NaN          NaN             NaN
# 2                        NaN        NaN          NaN             NaN
# 3                        NaN        NaN          NaN             NaN
# 4                        NaN        NaN          NaN             NaN
# 5                        NaN        NaN          NaN             NaN
# ...                      ...        ...          ...             ...
# 456344                   NaN        NaN          NaN             NaN
# 456345                   NaN        NaN          NaN             NaN
# 456346                   NaN        NaN          NaN             NaN
# 456347                   NaN        NaN          NaN             NaN
# 456348                   NaN        NaN          NaN             NaN
#
#         SMA_residential
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# ...                 ...
# 456344              NaN
# 456345              NaN
# 456346              NaN
# 456347              NaN
# 456348              NaN
#
# [40399 rows x 14 columns]

# %% [markdown]
# ## Store NYT COVID cases and deaths CSV into DataFrame

# %%
csv_file = "Resources/COVID-states.csv"
covid_data_df = pd.read_csv(csv_file)
covid_data_df.head()

# %%
covid_us = covid_data_df.rename(columns = {"state":'states', "fips": 'fips', "date":'dates', "cases":'cases',
                            "deaths":'deaths'})
covid_us.head()

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = f"{db_user}:{{db_pwd}}@localhost:5432/mobility_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
google_us.to_sql(name='google_data', con=engine, if_exists='append', index=False)

# %%
covid_us.to_sql(name='covid_data', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the tables

# %%
pd.read_sql_query('select * from google_data', con=engine).head(10)

# %%
pd.read_sql_query('select * from covid_data', con=engine).head(10)
